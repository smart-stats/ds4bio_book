# %%
# prompt: I want to connect Google drive and navigate to this directory

from google.colab import drive
drive.mount('/content/gdrive')

# %cd /content/gdrive/My Drive/work/sandboxes/ds4bio_book/qbook
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/My Drive/work/sandboxes/ds4bio_book/qbook

# %%
import os
os.chdir('/content/gdrive/My Drive/work/sandboxes/ds4bio_book/qbook')

# %%
## This does the installs
# %%bash
#pin pinstall jupyter-book
# Use conda I've found instead of pip
#pip install jupyter
#pip install matplotlib
#pip install numpy
#pip install pandas
#pip install scikit-learn
#pip install seaborn
#pip install scipy
#pip install PILLOW
#pip install urllib3
#pip install networkx
##pip install pytorch
##pip install torchvision
##pip install rpy2
##r-base r-tidyverse
##pip install r-irkernel
#pip install ipykernel
#pip install bs4
#pip install folium
#pip install streamlit
##pip install lxlm
#pip install statsmodels

# %%
# %%bash
# wget https://github.com/quarto-dev/quarto-cli/releases/download/v1.4.551/quarto-1.4.551-linux-amd64.tar.gz
# mkdir ~/opt
# tar -C ~/opt -xvzf quarto-1.4.551-linux-amd64.tar.gz
# mkdir ~/bin
# dir ~/bin
# ln -s ~/opt/quarto-1.4.551/bin/quarto ~/bin/quarto
# ~/bin/quarto install tinytex

# %%
#%%bash
#~/bin/quarto convert index.qmd
#~/bin/quarto convert intro.qmd
#~/bin/quarto convert intro_markdown.qmd
#~/bin/quarto convert intro_unix.qmd
#~/bin/quarto convert intro_git.qmd
#~/bin/quarto convert intro_html.qmd
#~/bin/quarto convert python.qmd
#~/bin/quarto convert python_basic.qmd
#~/bin/quarto convert python_programming.qmd
#~/bin/quarto convert python_functions.qmd
#~/bin/quarto convert python_virtual_environments.qmd
#~/bin/quarto convert python_practice.qmd
#~/bin/quarto convert data.qmd
#~/bin/quarto convert data_cleaning_example.qmd
#~/bin/quarto convert data_sqlite.qmd
#~/bin/quarto convert data_advanced_databases.qmd
#~/bin/quarto convert data_webscraping.qmd
#~/bin/quarto convert data_advanced_webscraping.qmd
#~/bin/quarto convert graphics.qmd
#~/bin/quarto convert graphics_eda.qmd
#~/bin/quarto convert graphics_interactive.qmd
#~/bin/quarto convert graphics_advanced_interactive.qmd
#~/bin/quarto convert graphics_theory.qmd
#~/bin/quarto convert graphics_images.qmd
#~/bin/quarto convert tooling.qmd
#~/bin/quarto convert tooling_nlp.qmd
#~/bin/quarto convert tooling_numpy.qmd
#~/bin/quarto convert tooling_streamlit.qmd
#~/bin/quarto convert tooling_dash.qmd
#~/bin/quarto convert statistics.qmd
#~/bin/quarto convert statistics_ml.qmd
#~/bin/quarto convert statistics_optimization.qmd
#~/bin/quarto convert statistics_causal.qmd
#~/bin/quarto convert supervised.qmd
#~/bin/quarto convert supervised_binary_classification.qmd
#~/bin/quarto convert supervised_regression_origin.qmd
#~/bin/quarto convert supervised_regression.qmd
#~/bin/quarto convert supervised_logistic.qmd
#~/bin/quarto convert supervised_multivariable.qmd
#~/bin/quarto convert supervised_dft.qmd
#~/bin/quarto convert unsupervised.qmd
#~/bin/quarto convert unsupervised_pca_ica.qmd
#~/bin/quarto convert nns.qmd
#~/bin/quarto convert nns_intro.qmd
#~/bin/quarto convert nns_basic_regression.qmd
#~/bin/quarto convert nns_logistic_regression.qmd
#~/bin/quarto convert nns_pytorch_example.qmd
#~/bin/quarto convert specialized.qmd
#~/bin/quarto convert specialized_autoencoder.qmd
#~/bin/quarto convert specialized_autoencoder2.qmd
#~/bin/quarto convert specialized_gan.qmd
#~/bin/quarto convert specialized_rnns.qmd
#~/bin/quarto convert specialized_gpu.qmd
#~/bin/quarto convert theory.qmd
#~/bin/quarto convert theory_explainability.qmd
#~/bin/quarto convert theory_data_analysis.qmd
#~/bin/quarto convert theory_measurement.qmd
#~/bin/quarto convert summary.qmd
#~/bin/quarto convert references.qmd

# %%
# %%bash
# ~/bin/quarto render
# Out:
# [1/5] index.qmd
# [2/5] intro.qmd
# [3/5] intro_markdown.qmd
# [4/5] summary.qmd
# [5/5] references.qmd
#
# pandoc
#   to: latex
#   output-file: index.tex
#   standalone: true
#   toc: true
#   number-sections: true
#   top-level-division: chapter
#   pdf-engine: xelatex
#   variables:
#     graphics: true
#     tables: true
#   default-image-extension: pdf
#
# metadata
#   crossref:
#     chapters: true
#   documentclass: scrreprt
#   papersize: letter
#   classoption:
#     - DIV=11
#     - numbers=noendperiod
#   header-includes:
#     - '\KOMAoption{captions}{tableheading}'
#   block-headings: true
#   bibliography:
#     - references.bib
#   title: Data science and AI for the biological and medical sciences using python
#   author: Brian Caffo
#   date: 2/24/2023
#
#
# Rendering PDF
# running xelatex - 1
#   This is XeTeX, Version 3.141592653-2.6-0.999996 (TeX Live 2024) (preloaded format=xelatex)
#    restricted \write18 enabled.
#   entering extended mode
#
# updating tlmgr
# ...
