# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pyglide &> /dev/null
# !sudo apt-get install pandoc &> /dev/null
# !sudo apt-get install texlive-xetex texlive-fonts-recommended texlive-plain-generic &> /dev/null
# !pip install nbconvert &> /dev/null

# %%
# %cd /content/drive/MyDrive/work/sandboxes/ds4bio_book/slides/summer_institute/
# Out:
# /content/drive/MyDrive/work/sandboxes/ds4bio_book/slides/summer_institute

# %%
# %ls
# Out:
#  01_welcome.ipynb                    06_data_cleaning.ipynb
#  01_welcome.slides.html              06_data_cleaning.slides.html
#  02_python_basics.ipynb              26_nns.ipynb
#  02_python_basics.slides.html        convolutions.ipynb
#  03_python_programming.ipynb        'Copy of convnet_classifier_pytorch.ipynb'
#  03_python_programming.slides.html   llm_example.ipynb
#  04_functions.ipynb                  make_slides_ds4bio_summer_institute.ipynb
#  04_functions.slides.html            node_modules/
#  05_python_practice.ipynb            package-lock.json
#  05_python_practice.slides.html      readme.md

# %%
import nbformat as nbf

# Load the notebook
with open("03_python_programming.ipynb", "r", encoding="utf-8") as f:
    nb = nbf.read(f, as_version=4)

# Edit the metadata
#nb["metadata"]["title"] = "My New Title"
#nb["metadata"]["author"] = "Your Name"

# Save the notebook
#with open("02_python_basics.ipynb", "w", encoding="utf-8") as f:
#    nbf.write(nb, f)

# %%
# %%bash
# jupyter nbconvert 01_welcome.ipynb --to slides  --template reveal &> /dev/null
# jupyter nbconvert 02_python_basics.ipynb --to slides  --template reveal &> /dev/null
# jupyter nbconvert 03_python_programming.ipynb --to slides  --template reveal &> /dev/null
# jupyter nbconvert 04_functions.ipynb --to slides  --template reveal &> /dev/null
# jupyter nbconvert 05_python_practice.ipynb --to slides  --template reveal &> /dev/null
# jupyter nbconvert 06_data_cleaning.ipynb --to slides  --template reveal &> /dev/null

# %%
# %ls *.html
# Out:
# 01_welcome.slides.html        04_functions.slides.html        06_data_cleaning.slides.html
# 02_python_basics.slides.html  05_python_practice.slides.html

# %%
# !npm install localtunnel &> /dev/null
# !python -m http.server 8506 &> /dev/null &

# %%
# !wget -q -O - https://loca.lt/mytunnelpassword
# Out:
# 104.155.196.52

# %%
# !npx localtunnel --port 8506
# Out:
# npx: installed 22 in 1.93s
# your url is: https://purple-moles-rhyme.loca.lt
