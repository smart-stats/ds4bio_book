# %% [markdown]
# # Welcome to the class!
# ## AI Programming in Python for Public Health
# ### Instructors: Brian Caffo and Ahmed Hassoon

# %% [markdown]
# ###  Course setup
# + Participation (10%) based on attendance
# + Quizzes (30%) done in class, require no prep
#    + Usually a set of programming tasks
# + Final project (60%) is due Sunday evening

# %% [markdown]
# ### Office hours
# + Immediately after class
# + TA office hour

# %% [markdown]
# ### Files
# + I'm trying to put all of the notes and slides in one place ("book"?)
#   + The base github directory [https://github.com/smart-stats/ds4bio_book](https://github.com/smart-stats/ds4bio_book)
#   + Live version of the notes [https://smart-stats.github.io/ds4bio_book/book/_build/html/intro.html](https://smart-stats.github.io/ds4bio_book/book/_build/html/intro.html)
#   + The slides can be found here [https://github.com/smart-stats/ds4bio_book/slides](https://github.com/smart-stats/ds4bio_book/slides/)
# + The old course site is here
#   + [https://github.com/bcaffo/ds4ph-bme](https://github.com/bcaffo/ds4ph-bme)
# + All other files distributed on the Teams site

# %% [markdown]
# ## Software
# + Python will be the base language for the course
# + We will do everything in [colab](https://colab.research.google.com/)
# + This is a jupyter and jupyter lab solution hosted by google
# + Rolling out your own python ide (we recommend [vscode](https://code.visualstudio.com/) is great, but we can't support any issues that you have)
# + If you want to install python, you might start with [anaconda](https://www.anaconda.com/)
